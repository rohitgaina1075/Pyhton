# %% [markdown]
# Dictionaries
#
# Video Outline:
#
# 1.Introduction to Dictionaries
# 2.Creating Dictionaries
# 3.Accessing Dictionary Elements
# 4.Modifying Dictionary Elements
# 5.Dictionary Methods
# 6.Iterating Over Dictionaries
# 7.Nested Dictionaries
# 8.Dictionary Comprehensions
# 9.Practical Examples and Common Errors
#
# Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
## Creating Dictionaries
empty_dict ={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %%
student = {"name":"Rohit","class":"Data science","age":23,"grade":24}
print(student)
print(type(student))
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 23, 'grade': 24}
# <class 'dict'>

# %%
# Single key is slways used
students = {"name":"Rohit","age":23,"name":24}
print(students)
print(type(students))
# Out:
# {'name': 24, 'age': 23}
# <class 'dict'>

# %%
## accessing Dictionary Elements
student = {"name":"Rohit","class":"Data science","age":23,"grade":"A"}
print(student)
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 23, 'grade': 'A'}

# %%
## Accessing Dictionary elements
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Available"))
# Out:
# A
# 23
# A
# None
# Not Available

# %%
## Modifying Dicitonary Elements
## Dictionary are mutable,so you can add, update or delete elements
print(student)
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 23, 'grade': 'A'}

# %%
student["age"] = 33 #update value for the key
print(student)
student["address"]="India" #added a new key and value
print(student)
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 33, 'grade': 'A'}
# {'name': 'Rohit', 'class': 'Data science', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade'] #delete key and value pair
print(student)
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 33, 'address': 'India'}

# %%
## Dictionary methods
keys= student.keys() #get all the keys
print(keys)
values=student.values()  #get all values
print(values)

items = student.items() #get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'class', 'age', 'address'])
# dict_values(['Rohit', 'Data science', 33, 'India'])
# dict_items([('name', 'Rohit'), ('class', 'Data science'), ('age', 33), ('address', 'India')])

# %%
## shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Rohit', 'class': 'Data science', 'age': 33, 'address': 'India'}
# {'name': 'Rohit', 'class': 'Data science', 'age': 33, 'address': 'India'}

# %%
student["name"]="RohitGaina"
print(student)
print(student_copy)
# Out:
# {'name': 'RohitGaina', 'class': 'Data science', 'age': 33, 'address': 'India'}
# {'name': 'RohitGaina', 'class': 'Data science', 'age': 33, 'address': 'India'}

# %%
student_copy1 = student.copy()  #shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'RohitGaina', 'class': 'Data science', 'age': 33, 'address': 'India'}
# {'name': 'RohitGaina', 'class': 'Data science', 'age': 33, 'address': 'India'}

# %%
student["name"]="Aman"
print("student_copy1")
print(student)
# Out:
# student_copy1
# {'name': 'Aman', 'class': 'Data science', 'age': 33, 'address': 'India'}

# %%
### Iterating Over Dictionaries
## You can use loops to iterate over dictionatries, keys,values,or items

## Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# class
# age
# address

# %%
## Iterate over values
for value in student.values():
    print(value)
# Out:
# Aman
# Data science
# 33
# India

# %%
## Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Aman
# class:Data science
# age:33
# address:India

# %%
## Nested Disctionaries
students = {
    "student1":{"name":"Aman","age":35},
    "student2":{"name":"Ram","age":33},
}
print(students)
# Out:
# {'student1': {'name': 'Aman', 'age': 35}, 'student2': {'name': 'Ram', 'age': 33}}

# %%
## Access nested dictionaries elementss
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Ram
# 33

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Aman', 'age': 35}), ('student2', {'name': 'Ram', 'age': 33})])

# %%
## Iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Aman', 'age': 35}
# name:Aman
# age:35
# student2:{'name': 'Ram', 'age': 33}
# name:Ram
# age:33

# %%
## Dictionary Comphrehension
squares = {x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Condition dictionary comprehension
evens = {x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## USe a dictionary to count he frequency of elements in list

numbers =[1,2,2,3,3,3,4,5,5,5,5,5,6,7]
frequency = {}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1, 5: 5, 6: 1, 7: 1}

# %%
## Merge 2 dictionaries into one

dict1 = {"a"}
