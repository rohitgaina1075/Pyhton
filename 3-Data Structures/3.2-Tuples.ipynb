# %% [markdown]
# Tuples
#
# Video Outline:
#
# 1.Introduction to Tuples
# 2.Creating Tuples
# 3.Accessing Tuple Elements
# 4.Tuple Operations
# 5.Immutable Nature of Tuples
# 6.Tuple Methods
# 7.Packing and Unpacking Tuples
# 8.Nested Tuples
# 9.Practical Examples and Common Errors
#
# Introduction to Tuples
#
# Explanation:
#
# Tuples are ordered collections of items that are immutable. They are similar to lists, but their immutability makes them different.

# %%
## creating a tuple
ematy_tuple=()
print(ematy_tuple)
print(type(ematy_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
print(type(number))
# Out:
# <class 'tuple'>

# %%
list([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple =("hello","hi",1,2,4,3.3,True)
print(mixed_tuple)
print(type(mixed_tuple))
# Out:
# ('hello', 'hi', 1, 2, 4, 3.3, True)
# <class 'tuple'>

# %%
## Accessing Tuple Elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(number[2])
print(number[0:4])
# Out:
# 3
# (1, 2, 3, 4)

# %%
print(number[-2])
# Out:
# 5

# %%
number[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuple Operations

concatenation_tuple = numbers + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 'hello', 'hi', 1, 2, 4, 3.3, True)

# %%
mixed_tuple*2
# Out:
# ('hello', 'hi', 1, 2, 4, 3.3, True, 'hello', 'hi', 1, 2, 4, 3.3, True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutable Nature Of Tuples
## Tuples are immutable, meaning their elements cannot be changed once assigned.

lst = [1,2,3,4,5]
print(lst)

lst[4]="Rohit"
print(lst)
print(type(lst))
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 'Rohit']
# <class 'list'>

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
## Tuple Methods
print(number.count(1))
print(number.index(3))
# Out:
# 1
# 2

# %%
## Packing and Unpacking tuple
## packing
packed_tuple = 1, "hi","hello",3.14
print(packed_tuple)
# Out:
# (1, 'hi', 'hello', 3.14)

# %%
##unpacking a tuple
a,b,c,d =packed_tuple
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# hi
# hello
# 3.14

# %%
## Unpacking with *
numbers = (1,2,3,4,5,6)
first,*middle,last = numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested Tuple
## Nested List
lst = [[1,2,3,4],[6,7,8,9],["hello","hi",3.14,4]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello",3.14,"c")]
lst[2][0:3]
# Out:
# (1, 'Hello', 3.14)

# %%
nested_tuple = ((1,2,3),("a","b","c"),(True,False))

## access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[2][1])
# Out:
# (1, 2, 3)
# False

# %%
## iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
